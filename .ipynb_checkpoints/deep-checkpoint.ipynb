# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorboard as tb
import datetime
from tensorflow.keras import layers

# %%
# %reload_ext tensorboard

# %%
# %tensorboard --logdir "logs/fit"
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# 2023-05-31 23:58:40.717775: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Address already in use
# Port 6006 is in use by another program. Either identify and stop that program, or start the server with a different port.

# %%
# Clear any logs from previous runs
# !rm -rf ./logs/

# %%
tf.__version__
# Out:
# '2.12.0'

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
csv_file = 'credit_customers.csv'
dataframe = pd.read_csv(csv_file)

# %%
#experiment_id = "c1KCv3X3QvGwaXfgX1c432"
#experiment = tb.data.experimental.ExperimentFromDev(experiment_id)
#df = experiment.get_scalars()
#df

# %%
dataframe['class'] = np.where(dataframe['class']=='bad', 0, 1)

# %%
dataframe[['sex', 'marriage']] = dataframe.personal_status.str.split(" ", expand = True)
dataframe.drop(['personal_status'], axis=1, inplace = True) # Personal status satırında cinsiyet ve medeni durum birlikte onları ayırıyoruz

# %%
train, val, test = np.split(dataframe.sample(frac=1), [int(0.8*len(dataframe)), int(0.9*len(dataframe))])

# %%
print(len(train), 'training examples')
print(len(val), 'validation examples')
print(len(test), 'test examples')
# Out:
# 800 training examples
# 100 validation examples
# 100 test examples

# %%
def df_to_dataset(dataframe, shuffle=True, batch_size=1):
  df = dataframe.copy()
  labels = df.pop('class')
  df = {key: value[:,tf.newaxis] for key, value in dataframe.items()}
  ds = tf.data.Dataset.from_tensor_slices((dict(df), labels))
  if shuffle:
    ds = ds.shuffle(buffer_size=len(dataframe))
  ds = ds.batch(batch_size)
  ds = ds.prefetch(batch_size)
  return ds

# %%
batch_size = 5
train_ds = df_to_dataset(train, batch_size=batch_size)
# Out:
# /tmp/ipykernel_68793/4009967357.py:4: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   df = {key: value[:,tf.newaxis] for key, value in dataframe.items()}

# %%
[(train_features, label_batch)] = train_ds.take(1)
print('Every feature:', list(train_features.keys()))
print('A batch of targets:', label_batch )
# Out:
# Every feature: ['checking_status', 'duration', 'credit_history', 'purpose', 'credit_amount', 'savings_status', 'employment', 'installment_commitment', 'other_parties', 'residence_since', 'property_magnitude', 'age', 'other_payment_plans', 'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone', 'foreign_worker', 'class', 'sex', 'marriage']
# A batch of targets: tf.Tensor([0 0 0 1 0], shape=(5,), dtype=int64)
# 2023-05-31 23:59:09.882297: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_18' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_18}}]]
# 2023-05-31 23:59:09.882986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_4}}]]

# %%
def get_normalization_layer(name, dataset):
  # Create a Normalization layer for the feature.
  normalizer = layers.Normalization(axis=None)

  # Prepare a Dataset that only yields the feature.
  feature_ds = dataset.map(lambda x, y: x[name])

  # Learn the statistics of the data.
  normalizer.adapt(feature_ds)

  return normalizer

# %%
def get_category_encoding_layer(name, dataset, dtype, max_tokens=None):
  # Create a layer that turns strings into integer indices.
  if dtype == 'string':
    index = layers.StringLookup(max_tokens=max_tokens)
  # Otherwise, create a layer that turns integer values into integer indices.
  else:
    index = layers.IntegerLookup(max_tokens=max_tokens)

  # Prepare a `tf.data.Dataset` that only yields the feature.
  feature_ds = dataset.map(lambda x, y: x[name])

  # Learn the set of possible values and assign them a fixed integer index.
  index.adapt(feature_ds)

  # Encode the integer indices.
  encoder = layers.CategoryEncoding(num_tokens=index.vocabulary_size())

  # Apply multi-hot encoding to the indices. The lambda function captures the
  # layer, so you can use them, or include them in the Keras Functional model later.
  return lambda feature: encoder(index(feature))

# %%
categoricals=[]
numericals=[]
for l,k in dataframe.items():
    if k.dtype=='O':
        categoricals.append(l)
    else:
        numericals.append(l)
print(categoricals)
print(numericals)
# Out:
# ['checking_status', 'credit_history', 'purpose', 'savings_status', 'employment', 'other_parties', 'property_magnitude', 'other_payment_plans', 'housing', 'job', 'own_telephone', 'foreign_worker', 'sex', 'marriage']
# ['duration', 'credit_amount', 'installment_commitment', 'residence_since', 'age', 'existing_credits', 'num_dependents', 'class']

# %%
numericals.remove('class')
numericals
# Out:
# ['duration',
#  'credit_amount',
#  'installment_commitment',
#  'residence_since',
#  'age',
#  'existing_credits',
#  'num_dependents']

# %%
batch_size = 32
train_ds = df_to_dataset(train, batch_size=batch_size)
val_ds = df_to_dataset(val, shuffle=False, batch_size=batch_size)
test_ds = df_to_dataset(test, shuffle=False, batch_size=batch_size)
# Out:
# /tmp/ipykernel_68793/4009967357.py:4: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   df = {key: value[:,tf.newaxis] for key, value in dataframe.items()}
# /tmp/ipykernel_68793/4009967357.py:4: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   df = {key: value[:,tf.newaxis] for key, value in dataframe.items()}
# /tmp/ipykernel_68793/4009967357.py:4: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   df = {key: value[:,tf.newaxis] for key, value in dataframe.items()}

# %%
all_inputs = []
encoded_features = []

# Numerical features.
for header in numericals:
  numeric_col = tf.keras.Input(shape=(1,), name=header)
  normalization_layer = get_normalization_layer(header, train_ds)
  encoded_numeric_col = normalization_layer(numeric_col)
  all_inputs.append(numeric_col)
  encoded_features.append(encoded_numeric_col)
# Out:
# 2023-05-31 23:59:10.193127: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_8' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_8}}]]
# 2023-05-31 23:59:10.193686: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_21' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_21}}]]
# 2023-05-31 23:59:10.357473: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype double and shape [800,1]
# 	 [[{{node Placeholder/_7}}]]
# 2023-05-31 23:59:10.358084: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_19' with dtype double and shape [800,1]
# 	 [[{{node Placeholder/_19}}]]
# 2023-05-31 23:59:10.514662: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [800,1]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-31 23:59:10.515300: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_21' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_21}}]]
# 2023-05-31 23:59:10.671968: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_17' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_17}}]]
# 2023-05-31 23:59:10.672588: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_15' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_15}}]]
# 2023-05-31 23:59:10.827743: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_21' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_21}}]]
# 2023-05-31 23:59:10.828289: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_14' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_14}}]]
# 2023-05-31 23:59:10.975310: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_1}}]]
# 2023-05-31 23:59:10.975861: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_8' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_8}}]]
# 2023-05-31 23:59:11.119844: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_6' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_6}}]]
# 2023-05-31 23:59:11.120382: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_11}}]]

# %%
for header in categoricals:
  categorical_col = tf.keras.Input(shape=(1,), name=header, dtype='string')
  encoding_layer = get_category_encoding_layer(name=header,
                                               dataset=train_ds,
                                               dtype='string',
                                               max_tokens=5)
  encoded_categorical_col = encoding_layer(categorical_col)
  all_inputs.append(categorical_col)
  encoded_features.append(encoded_categorical_col)
# Out:
# 2023-05-31 23:59:11.260989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_6' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_6}}]]
# 2023-05-31 23:59:11.261554: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_21' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_21}}]]
# 2023-05-31 23:59:11.350154: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_17' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_17}}]]
# 2023-05-31 23:59:11.350711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_9' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_9}}]]
# 2023-05-31 23:59:11.428137: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_21' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_21}}]]
# 2023-05-31 23:59:11.428680: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_19' with dtype double and shape [800,1]
# 	 [[{{node Placeholder/_19}}]]
# 2023-05-31 23:59:11.510200: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [800,1]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-31 23:59:11.510793: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [800,1]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-31 23:59:11.601877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_12' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_12}}]]
# 2023-05-31 23:59:11.602413: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_4}}]]
# 2023-05-31 23:59:11.679941: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_6' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_6}}]]
# 2023-05-31 23:59:11.680511: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_16' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_16}}]]
# 2023-05-31 23:59:11.758954: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_8' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_8}}]]
# 2023-05-31 23:59:11.759499: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_6' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_6}}]]
# 2023-05-31 23:59:11.839375: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_9' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_9}}]]
# 2023-05-31 23:59:11.839918: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype double and shape [800,1]
# 	 [[{{node Placeholder/_10}}]]
# 2023-05-31 23:59:11.915824: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_22' with dtype int64 and shape [800]
# 	 [[{{node Placeholder/_22}}]]
# 2023-05-31 23:59:11.916360: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_19' with dtype double and shape [800,1]
# 	 [[{{node Placeholder/_19}}]]
# 2023-05-31 23:59:12.000180: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_15' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_15}}]]
# 2023-05-31 23:59:12.000770: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_14' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_14}}]]
# 2023-05-31 23:59:12.083999: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_6' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_6}}]]
# 2023-05-31 23:59:12.084544: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_19' with dtype double and shape [800,1]
# 	 [[{{node Placeholder/_19}}]]
# 2023-05-31 23:59:12.165351: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_8' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_8}}]]
# 2023-05-31 23:59:12.165897: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_5' with dtype double and shape [800,1]
# 	 [[{{node Placeholder/_5}}]]
# 2023-05-31 23:59:12.244571: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_21' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_21}}]]
# 2023-05-31 23:59:12.245175: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_8' with dtype string and shape [800,1]
# 	 [[{{node Placeholder/_8}}]]
# 2023-05-31 23:59:12.323277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype double and shape [800,1]
# 	 [[{{node Placeholder/_3}}]]
# 2023-05-31 23:59:12.323817: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_22' with dtype int64 and shape [800]
# 	 [[{{node Placeholder/_22}}]]

# %%
all_features = tf.keras.layers.concatenate(encoded_features)
x = tf.keras.layers.Dense(32, activation="relu")(all_features)
x = tf.keras.layers.Dropout(0.5)(x)
output = tf.keras.layers.Dense(1)(x)

model = tf.keras.Model(all_inputs, output)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=["accuracy"])

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=0)

# %%
# Use `rankdir='LR'` to make the graph horizontal.
tf.keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %%
model.fit(train_ds, epochs=100, validation_data=val_ds,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/100
# 2023-05-31 23:59:12.934356: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_22' with dtype int64 and shape [800]
# 	 [[{{node Placeholder/_22}}]]
# 2023-05-31 23:59:12.935032: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_22' with dtype int64 and shape [800]
# 	 [[{{node Placeholder/_22}}]]
# /home/usern/projects/DL/.venv/lib/python3.11/site-packages/keras/engine/functional.py:639: UserWarning: Input dict contained keys ['class'] which did not match any model input. They will be ignored by the model.
#   inputs = self._flatten_to_reference_inputs(inputs)
# 23/25 [==========================>...] - ETA: 0s - loss: 0.6857 - accuracy: 0.4959
# 2023-05-31 23:59:13.842488: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype double and shape [100,1]
# 	 [[{{node Placeholder/_10}}]]
# 2023-05-31 23:59:13.843043: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_5' with dtype double and shape [100,1]
# 	 [[{{node Placeholder/_5}}]]
# 25/25 [==============================] - 1s 17ms/step - loss: 0.6832 - accuracy: 0.4925 - val_loss: 0.7484 - val_accuracy: 0.5400
# Epoch 2/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6148 - accuracy: 0.6187 - val_loss: 0.7385 - val_accuracy: 0.5900
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5950 - accuracy: 0.6625 - val_loss: 0.7140 - val_accuracy: 0.6300
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5865 - accuracy: 0.6500 - val_loss: 0.6915 - val_accuracy: 0.6700
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5527 - accuracy: 0
# Epoch 56/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4006 - accuracy: 0.8012 - val_loss: 0.6421 - val_accuracy: 0.6800
# Epoch 57/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3892 - accuracy: 0.8050 - val_loss: 0.6478 - val_accuracy: 0.6700
# Epoch 58/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3942 - accuracy: 0.8263 - val_loss: 0.6506 - val_accuracy: 0.6700
# Epoch 59/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4057 - accuracy: 0.8000 - val_loss: 0.6360 - val_accuracy: 0.6600
# Epoch 60/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3824 - accuracy: 0.8112 - val_loss: 0.6565 - val_accuracy: 0.6700
# Epoch 61/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3855 - accuracy: 0.8225 - val_loss: 0.6506 - val_accuracy: 0.6700
# Epoch 62/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3814 - accuracy: 0.8100 - val_loss: 0.6547 - val_accuracy: 0.6600
# Epoch 63/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3830 - accuracy: 0.8188 - val_loss: 0.6544 - val_accuracy: 0.6600
# Epoch 64/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3833 - accuracy: 0.8263 - val_loss: 0.6459 - val_accuracy: 0.6600
# Epoch 65/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3865 - accuracy: 0.8213 - val_loss: 0.6495 - val_accuracy: 0.6700
# Epoch 66/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3844 - accuracy: 0.8138 - val_loss: 0.6512 - val_accuracy: 0.6900
# Epoch 67/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3794 - accuracy: 0.8288 - val_loss: 0.6605 - val_accuracy: 0.6600
# Epoch 68/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3905 - accuracy: 0.8100 - val_loss: 0.6393 - val_accuracy: 0.6800
# Epoch 69/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3808 - accuracy: 0.8163 - val_loss: 0.6498 - val_accuracy: 0.6800
# Epoch 70/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3749 - accuracy: 0.8300 - val_loss: 0.6590 - val_accuracy: 0.6800
# Epoch 71/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3673 - accuracy: 0.8300 - val_loss: 0.6614 - val_accuracy: 0.6700
# Epoch 72/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.8462 - val_loss: 0.6597 - val_accuracy: 0.6800
# Epoch 73/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3832 - accuracy: 0.8138 - val_loss: 0.6613 - val_accuracy: 0.6700
# Epoch 74/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3594 - accuracy: 0.8288 - val_loss: 0.6795 - val_accuracy: 0.6700
# Epoch 75/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3669 - accuracy: 0.8238 - val_loss: 0.6624 - val_accuracy: 0.6900
# Epoch 76/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3623 - accuracy: 0.8313 - val_loss: 0.6775 - val_accuracy: 0.6800
# Epoch 77/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3629 - accuracy: 0.8250 - val_loss: 0.6669 - val_accuracy: 0.6900
# Epoch 78/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3829 - accuracy: 0.8288 - val_loss: 0.6469 - val_accuracy: 0.6800
# Epoch 79/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3584 - accuracy: 0.8213 - val_loss: 0.6654 - val_accuracy: 0.6800
# Epoch 80/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3586 - accuracy: 0.8112 - val_loss: 0.6731 - val_accuracy: 0.6600
# Epoch 81/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.8325 - val_loss: 0.6807 - val_accuracy: 0.6700
# Epoch 82/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3467 - accuracy: 0.8450 - val_loss: 0.6682 - val_accuracy: 0.6600
# Epoch 83/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3618 - accuracy: 0.8313 - val_loss: 0.6782 - val_accuracy: 0.6700
# Epoch 84/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3577 - accuracy: 0.8350 - val_loss: 0.6677 - val_accuracy: 0.6700
# Epoch 85/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3478 - accuracy: 0.8475 - val_loss: 0.6714 - val_accuracy: 0.6600
# Epoch 86/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3535 - accuracy: 0.8313 - val_loss: 0.6793 - val_accuracy: 0.6600
# Epoch 87/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3578 - accuracy: 0.8425 - val_loss: 0.6875 - val_accuracy: 0.6600
# Epoch 88/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3568 - accuracy: 0.8325 - val_loss: 0.6714 - val_accuracy: 0.6600
# Epoch 89/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3689 - accuracy: 0.8350 - val_loss: 0.6755 - val_accuracy: 0.6600
# Epoch 90/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3609 - accuracy: 0.8200 - val_loss: 0.6570 - val_accuracy: 0.6700
# Epoch 91/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3487 - accuracy: 0.8275 - val_loss: 0.6822 - val_accuracy: 0.6600
# Epoch 92/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3571 - accuracy: 0.8338 - val_loss: 0.6729 - val_accuracy: 0.6600
# Epoch 93/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3522 - accuracy: 0.8363 - val_loss: 0.6720 - val_accuracy: 0.6600
# Epoch 94/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3325 - accuracy: 0.8537 - val_loss: 0.6799 - val_accuracy: 0.6600
# Epoch 95/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3621 - accuracy: 0.8213 - val_loss: 0.6794 - val_accuracy: 0.6600
# Epoch 96/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3556 - accuracy: 0.8350 - val_loss: 0.6868 - val_accuracy: 0.6600
# Epoch 97/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3417 - accuracy: 0.8350 - val_loss: 0.6847 - val_accuracy: 0.6600
# Epoch 98/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3346 - accuracy: 0.8525 - val_loss: 0.6954 - val_accuracy: 0.6600
# Epoch 99/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3396 - accuracy: 0.8487 - val_loss: 0.6845 - val_accuracy: 0.6600
# Epoch 100/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3360 - accuracy: 0.8475 - val_loss: 0.6909 - val_accuracy: 0.6600

# %%
loss, accuracy = model.evaluate(test_ds)
print("Accuracy", accuracy)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3674 - accuracy: 0.8100
# Accuracy 0.8100000023841858
# 2023-05-31 23:59:22.142327: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype double and shape [100,1]
# 	 [[{{node Placeholder/_7}}]]
# 2023-05-31 23:59:22.142876: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [100,1]
# 	 [[{{node Placeholder/_0}}]]

# %%
#model.save('exportedModelacc82')
#reloaded_model = tf.keras.models.load_model('my_pet_classifier')
